# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#      year              sector       class  \
# 0    2009  Central government       Total
# 1    2010  Central government       Total
# 2    2011  Central government       Total
# 3    2012  Central government       Total
# 4    2013  Central government       Total
# ..    ...                 ...         ...
# 469  2016    Local government  Wastewater
# 470  2017    Local government  Wastewater
# 471  2018    Local government  Wastewater
# 472  2019    Local government  Wastewater
# 473  2020    Local government  Wastewater
#
#                                  cfn_tle1                       cfn_tle2  \
# 0    Environmental protection expenditure  Final consumption expenditure
# 1    Environmental protection expenditure  Final consumption expenditure
# 2    Environmental protection expenditure  Final consumption expenditure
# 3    Environmental protection expenditure  Final consumption expenditure
# 4    Environmental protection expenditure  Final consumption expenditure
# ...

# %%
data = pd.read_csv("dataset.csv",usecols=["year","sector", "class","cfn_tle2", "units","data_value"])
data
# Out:
#      year              sector       class                       cfn_tle2  \
# 0    2009  Central government       Total  Final consumption expenditure
# 1    2010  Central government       Total  Final consumption expenditure
# 2    2011  Central government       Total  Final consumption expenditure
# 3    2012  Central government       Total  Final consumption expenditure
# 4    2013  Central government       Total  Final consumption expenditure
# ..    ...                 ...         ...                            ...
# 469  2016    Local government  Wastewater  Gross fixed capital formation
# 470  2017    Local government  Wastewater  Gross fixed capital formation
# 471  2018    Local government  Wastewater  Gross fixed capital formation
# 472  2019    Local government  Wastewater  Gross fixed capital formation
# 473  2020    Local government  Wastewater  Gross fixed capital formation
#
#           units  data_value
# 0    Proportion         1.2
# 1    Proportion         1.2
# ...

# %%
df_new = data[(data['class'] == "Total") & (data['units'] == "Proportion") & (data['sector'] == "Central government") & (data['cfn_tle2'] == "Final consumption expenditure")]
df_new
# Out:
#     year              sector  class                       cfn_tle2  \
# 0   2009  Central government  Total  Final consumption expenditure
# 1   2010  Central government  Total  Final consumption expenditure
# 2   2011  Central government  Total  Final consumption expenditure
# 3   2012  Central government  Total  Final consumption expenditure
# 4   2013  Central government  Total  Final consumption expenditure
# 5   2014  Central government  Total  Final consumption expenditure
# 6   2015  Central government  Total  Final consumption expenditure
# 7   2016  Central government  Total  Final consumption expenditure
# 8   2017  Central government  Total  Final consumption expenditure
# 9   2018  Central government  Total  Final consumption expenditure
# 10  2019  Central government  Total  Final consumption expenditure
# 11  2020  Central government  Total  Final consumption expenditure
# 12  2021  Central government  Total  Final consumption expenditure
#
#          units  data_value
# ...

# %%
bargraph = df_new.plot.bar(x = 'year', y = 'data_value', fontsize='15',figsize = (14, 4))

# %%
df_new2 = data[(data['class'] == "Total") & (data['units'] == "Proportion") & (data['sector'] == "Local government") & (data['cfn_tle2'] == "Final consumption expenditure") ]
df_new2
# Out:
#      year            sector  class                       cfn_tle2       units  \
# 348  2009  Local government  Total  Final consumption expenditure  Proportion
# 349  2010  Local government  Total  Final consumption expenditure  Proportion
# 350  2011  Local government  Total  Final consumption expenditure  Proportion
# 351  2012  Local government  Total  Final consumption expenditure  Proportion
# 352  2013  Local government  Total  Final consumption expenditure  Proportion
# 353  2014  Local government  Total  Final consumption expenditure  Proportion
# 354  2015  Local government  Total  Final consumption expenditure  Proportion
# 355  2016  Local government  Total  Final consumption expenditure  Proportion
# 356  2017  Local government  Total  Final consumption expenditure  Proportion
# 357  2018  Local government  Total  Final consumption expenditure  Proportion
# 358  2019  Local government  Total  Final consumption expenditure  Proportion
# ...

# %%
bargraph = df_new2.plot.bar(x = 'year', y = 'data_value', fontsize='15',figsize = (14, 4))

# %%
xvals = df_new["data_value"]
yvals = df_new2["data_value"]
X = df_new["year"]
 
width = 0.25
  
xvals = df_new["data_value"]
bar1 = plt.bar(X, xvals, width, color = 'r')
  
yvals = df_new2["data_value"]
bar2 = plt.bar(X-width, yvals, width, color='g')
   
plt.xlabel("Central")
plt.ylabel('Local')
plt.title("Expendeture")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy import stats

x = df_new2["year"]
y = df_new2["data_value"]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy import stats

x = df_new["year"]
y = df_new["data_value"]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
j=0
for i in df_new["data_value"]:
    j=j+i

k= 0
for l in df_new2["data_value"]:
    k=k+l

y = np.array([j, k])

plt.pie(y, labels = mylabels)
plt.show()
